# %%
class Cachorro:
    cachorros = []

    def __init__(self, nome, raca):
        self._nome = nome.title()
        self._raca = raca.upper()
        self._disponibilidade = True
        Cachorro.cachorros.append(self)

    def __str__(self):
        return f'{self._nome} | {self._raca}'

    # Properties
    @property
    def nome(self):
        return self._nome

    @property
    def raca(self):
        return self._raca

    @property
    def disponibilidade(self):
        return 'Disponível' if self._disponibilidade else 'Indisponível'

    # Método de instância
    def alternar_estado(self):
        self._disponibilidade = not self._disponibilidade

    # Método de classe
    @classmethod
    def listar_cachorros(cls):
        print(f"{'Nome'.ljust(25)} | {'Raça'.ljust(25)} | {'Disponibilidade'}")
        print('-' * 70)
        for cachorro in cls.cachorros:
            print(
                f"{cachorro._nome.ljust(25)} | "
                f"{cachorro._raca.ljust(25)} | "
                f"{cachorro.disponibilidade}"
            )

# %%
pitbull_marrom = Cachorro('Pantera', 'Pitbull - Red Nose')

# %%
caramelo_peludo = Cachorro('Estopa', 'Sem raça definida')

# %%
rex = Cachorro('rex', 'labrador')

# %%
bob = Cachorro('bob', 'golden retriever')

# %%
pitbull_marrom.alternar_estado()
bob.alternar_estado()

# %%
Cachorro.listar_cachorros()
# Out:
# Nome                      | Raça                      | Disponibilidade
# ----------------------------------------------------------------------
# Pantera                   | PITBULL - RED NOSE        | Indisponível
# Estopa                    | SEM RAÇA DEFINIDA         | Disponível
# Rex                       | LABRADOR                  | Disponível
# Bob                       | GOLDEN RETRIEVER          | Indisponível

# %%
print(f"\nNome do primeiro cachorro: {pitbull_marrom.nome}")
print(f"Raça: {pitbull_marrom.raca}")
print(f"Disponibilidade: {pitbull_marrom.disponibilidade}")
# Out:
# Nome do primeiro cachorro: Pantera
# Raça: PITBULL - RED NOSE
# Disponibilidade: Indisponível
